# %% [markdown]
# ## emcee implementation of MCMC wrapper around DUSTY
#
# under construction

# %%
# %matplotlib inline
import numpy as np
from astropy.io import ascii
from os import system
import emcee
import matplotlib.pyplot as plt
import corner
import time

# %%
minlogTstar = 3.54
maxlogTstar = 4.60

# %%
def rl(rv,x):
    "rv is typically 3.1, x is 1/lambda [microns^-1]"
    if x < 1.1:
        a =  0.574*x**1.61
        b = -0.527*x**1.61
    else:
        if x < 3.3:
            y = x-1.82
            a = (1.0+0.17699*y-0.50447*y*y-0.02427*y**3+0.72085*y**4 + 0.01979*y**5-0.77530*y**6+0.32999*y**7)
            b = (1.41338*y+2.28305*y**2+1.07233*y**3-5.38434*y**4-0.62251*y**5+5.30260*y**6-2.09002*y**7)
        else:
            if x < 5.9:
                fa = 0.0
                fb = 0.0
            else:
                fa = -0.04473*(x-5.9)**2 - 0.009779*(x-5.9)**3
                fb =  0.21300*(x-5.9)**2 + 0.120700*(x-5.9)**3
            a =  1.752 - 0.316*x - 0.104/((x-4.67)**2+0.341) + fa
            b = -3.090 + 1.825*x + 1.206/((x-4.67)**2+0.263) + fb
    rlval = rv*(a+b/rv)
    return rlval

# %%
def locate(xx,n,x):
  jl = 0
  ju = n+1
  while ju - jl > 1:
    jm = (ju+jl) / 2
    if (xx[n-1] > xx[0] and x > xx[jm-1] ) or (xx[n-1] < xx[0] and x < xx[jm-1]):
      jl = jm
    else:
      ju = jm
  j = jl
  return j

def geninput(tstar,tau,td,thick,ebv,idtype,fileuse):
  output = open('foo1.inp','w')
  if (tstar < 3500 or tstar > 48999) or (blackbody):
    output.write('Spectrum = 1\n')
    output.write('Number of BB = 1\n')
    output.write('Temperature = %0.2f\n' % (tstar))
  else:
    output.write('Spectrum = 5   \n')
    output.write('%s\n' % (fileuse))
  output.write('   optical properties index = 1 \n')
  output.write('   #   Sil-Ow  Sil-Oc  Sil-DL  grf-DL  amC-Hn  SiC-Pg \n')
  if idtype == 0:
    output.write('    x = 0.00    0.00   0.00    1.00    0.00    0.00 \n')
  else:
    output.write('    x = 0.00    0.00   1.00    0.00    0.00    0.00 \n')
  if custom_grain_distribution:
    output.write('- size distribution = 2  % custom       \n')
    output.write('  q = 3.5, a(min) = %s micron, a(max) = %s micron\n' % (aminnew,amaxnew))
  else:
    output.write('- size distribution = 1  % standard MRN    \n')
  output.write('- temperature = %s K \n' % (td))
  output.write('- density type = 1                   \n')
  output.write('- number of powers = 1              \n')
  output.write('- shells relative thickness = %s\n' % (thick))
  output.write('- power = 2 \n')
  output.write('- grid type = 1                  % linear grid \n')
  output.write('- lambda0 = 0.55 micron          % optical depth specified  \n')
  output.write('- tau(min) = '+str(tau)+' ; tau(max) = 1000.0   % for the visual wavelength \n')
  output.write('- number of models = 1           \n')
  output.write('- accuracy for flux conservation = 0.05             \n')
  output.write('- verbosity flag;                              verbose = 1  \n')
  output.write('- properties of emerging spectra;            fname.spp = 1  \n')
  output.write('- detailed spectra for each model;          fname.s### = 1  \n')
  output.write('- images at specified wavelengths;          fname.i### = 1  \n')
  output.write('     number of wavelengths = 5  \n')
  output.write('     wavelengths = 3.5, 4.5, 6.0, 8.0, 24.0 micron  \n')
  output.write('- radial profiles for each model;           fname.r### = 1  \n')
  output.write('- detailed run-time messages;               fname.m### = 1  \n')
  output.write('- visibility function at spec. wavelengths; fname.v### = 0  \n')
  output.close()

  if verbose: print 'calling dusty with tstar = %0.1f; tau = %0.2f; td = %0.1f; thick = %0.2f; amin = %0.3f amax = %0.3f; E(B-V) = %0.4f; R_V = %0.2f' % (tstar,tau,td,thick,aminnew,amaxnew,ebv,rvnew)
  system('./dusty')

  ierror = 0
  #try:
  data = ascii.read('foo1.stb')
  lam = data['col1']
  flx = data['col2']
  npt = len(lam)

  i = 0
  with open('foo1.out','r') as f:
    for line in f:
      if i == 42:
        # print 'line read in from foo1.out:', line
        line_s = line.split()
        id = int(line_s[0])
        tau0 = float(line_s[1])
        f1 = float(line_s[2])
        r1 = float(line_s[3])
        r1torstar = float(line_s[4])
        theta1 = float(line_s[5])
        tdout = float(line_s[6])
        break
      i += 1
  #except:
  #  ierror = 1
  #  lam = np.nan
  #  flx = np.nan
  #  npt = np.nan
  #  r1 = np.nan
  return lam, flx, npt, r1, ierror

# %%
# let's start with the simplest scenario of fitting a blackbody temperature 
#   to a set of photometric constraints
def lnprior(theta):
    #tstarnew, taunew, tdnew, thicknew, ebvnew = theta
    ltstarnew, lebvnew = theta
    if (minlogTstar < ltstarnew < maxlogTstar) and (lebvnew < lmaxebv):
        if debug: print 'proposing tstar = %d' % (tstarnew)
        return 0.0
    if debug: print 'not proposing tstar = %d' % (tstarnew)
    return -np.inf

def lnlike(theta, mlumobs, merrobs):
    ltstarnew, lebvnew = theta
    tstarnew = 10**ltstarnew
    ebvnew = 10**lebvnew
    #tstarnew, taunew, tdnew, thicknew, ebvnew = theta
    lam, flx, npt, r1, ierror = geninput(tstarnew,taunew,tdnew,thicknew,ebvnew,idtype,fileuse)
    if ierror == 1:
        #if verbose: print 'had error, trying new model'
        #continue
        print 'IO error with geninput'
    # convert magnitudes to take out effect of extinction
    # mlum mlam lebvnew
    # ecor = 10.0**(-0.4*rval*ebvnew)
    mlum = np.zeros(len(mlumobs))
    merr = np.zeros(len(mlumobs))
    if veryverbose: print 'Extinction-corrected luminosities:'
    for i in xrange(len(mlam)):
        rlval = rl(rv,1.0/mlam[i])
        ecor = 10.0**(-0.4*rlval*ebvnew)
        mlum[i] = mlumobs[i] / ecor
        merr[i] = merrobs[i] / ecor
    if veryverbose: print '    %s %s %s %s (%s)' % (mlam[i], mlum[i], merr[i], filters[i], ecor)
    gtzero = (mlum > 0)
    ltzero = np.invert(gtzero)
    mluml = np.zeros(len(mlumobs))
    merrl = np.zeros(len(mlumobs))
    mluml[gtzero] = np.log10(mlum[gtzero])
    merrl[gtzero] = merr[gtzero]/mlum[gtzero]/np.log(10)
    merrl[ltzero] = np.log10(merr[ltzero])
    # loop through filters with luminosity constraints
    aa = 0.0
    bb = 0.0
    val = np.zeros(100)
    vall = np.zeros(100)
    for i in xrange(nm):
        j = locate(lam,npt,mlam[i]) - 1     # -1 because indexed to 0
        val[i] = flx[j] + (flx[j+1]-flx[j])*(mlam[i]-lam[j])/(lam[j+1]-lam[j])
        if debug: print 'i,j ',i,j,flx[j],flx[j+1],lam[j],lam[j+1],mlam[i],val[i]
        #print 'val[%s] = %s' % (i,val[i])
        # This is the luminosity chi^2 minimization
        vall[i] = np.log10(val[i]+1.e-32)
        if debug: print 'vall[%s] = %s' % (i,vall[i])
        if mlum[i] > 0:
            aa = aa + (mluml[i]-vall[i])/merrl[i]**2
            bb = bb + 1.0/merrl[i]**2
    sluml = aa/bb
    # r1 output from DUSTY is the distance at which a point source w/luminosity 10^4 L_sun produces the bolometric flux F_e1
    r1 = np.log10(r1) + 0.5*(sluml-4.0)   # scale radius for luminosity
    r2 = r1 + np.log10(thicknew)
    # dusty reports a radius scaled to a luminosity of 10^4
    # so this scales it to the luminosity you just worked out
    chi = 0.0
    chis = {}
    for i in xrange(nm):
        if mlum[i] > 0:
            chis[filters[i]] = ((mluml[i]-sluml-vall[i])/merrl[i])**2
            chi = chi + chis[filters[i]]
            #chi = chi + ((mluml[i]-sluml-vall[i])/merrl[i])**2
            if debug: print '%s = chi + ((%s-%s-%s)/%s)**2' % (chi,mluml[i],sluml,vall[i],merrl[i])
        if mlum[i] < 0:
            rat = 10.0**(sluml+vall[i]-merrl[i])
            if debug: print 'rat = %s = 10**(%s+%s-%s)' % (rat,sluml,vall[i],merrl[i])
            chis[filters[i]] = rat*rat
            chi = chi + chis[filters[i]]
            #chi = chi + rat*rat
    if debug: print 'tstar = %d -> chi2 = %0.1f' % (tstarnew, chi)
    return -0.5*chi

def lnprob(theta, mlumobs, merrobs):
    lp = lnprior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + lnlike(theta, mlumobs, merrobs)

# %%
verbose = False
veryverbose = False
blackbody = True
photometry_file = '/scr/sma/m31/dusty/progHSTSST_nodust_ebv0p15/preHSTSSTmags_ebv0p15.dat'

# %%
# read in the photometry file (magnitudes, filters)
data = ascii.read(photometry_file)
mlam = data['col1']
mlumobs = data['col2']
#mlumlobs = np.zeros(len(mlumobs))
#merrlobs = np.zeros(len(mlumobs))
#gtzero = (mlumobs > 0)
#ltzero = np.invert(gtzero)
#mlumlobs[gtzero] = np.log10(mlumobs[gtzero])
merrobs = data['col3']
#merrlobs[gtzero] = merrobs[gtzero]/mlumobs[gtzero]/np.log(10)
#merrlobs[ltzero] = np.log10(merrobs[ltzero])
filters = data['col4']
#templam, trans = read_filters(filters)
nm = np.shape(mlumobs)[0]
if verbose: print 'read %d data points' % (nm)
# Out:
# read 6 data points

# %%
tstarnew = 3600
taunew = 0
tdnew = 250
thicknew = 2
ebvnew = 0
idtype = 1
fileuse = ''
custom_grain_distribution = False
debug = False
aminnew = 0.005
amaxnew = 0.25
rvnew = 3.1
rv = 3.1
theta = [tstarnew, ebvnew]
lnlike(theta, mlumobs, merrobs)
# Out:
# calling dusty with tstar = 3600.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0000; R_V = 3.10
# -12.870999764826115

# %%
nwalkers = 8
ndim = 2

# Initialize the chain
# Choice 1: chain uniformly distributed in the range of the parameters
pos_min = np.array([3600,0])
pos_max = np.array([10000,0.5])
psize = pos_max - pos_min
pos = [pos_min + psize*np.random.rand(ndim) for i in range(nwalkers)]

# Visualize the initialization

fig = corner.corner(pos, labels=["$T_{*}$","$E(B-V)$"], extents=[[3600, 10000], [0, 0.5]], 
                      truths=[4000, 0.2])
fig.set_size_inches(10,10)
# Out:
# WARNING:root:Deprecated keyword argument 'extents'. Use 'range' instead.
# WARNING:root:Too few points to create valid contours

# %%
sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob, args=(mlumobs, merrobs))

# %%
#time0 = time.time()
# burnin phase
#pos, prob, state  = sampler.run_mcmc(pos, 10)
#sampler.reset()
#time1=time.time()
#print time1-time0
#time0 = time.time()
# perform MCMC
pos, prob, state  = sampler.run_mcmc(pos, 200)
time1=time.time()
print time1-time0
samples = sampler.flatchain
samples.shape
# Out:
# calling dusty with tstar = 9384.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2417; R_V = 3.10
# calling dusty with tstar = 5389.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0814; R_V = 3.10
# calling dusty with tstar = 7593.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3633; R_V = 3.10
# calling dusty with tstar = 9103.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1090; R_V = 3.10
# calling dusty with tstar = 7267.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0545; R_V = 3.10
# calling dusty with tstar = 4886.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2736; R_V = 3.10
# calling dusty with tstar = 8586.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4118; R_V = 3.10
# calling dusty with tstar = 5434.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4234; R_V = 3.10
# calling dusty with tstar = 9661.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2397; R_V = 3.10
# calling dusty with tstar = 4938.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0348; R_V = 3.10
# calling dusty with tstar = 6932.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3817; R_V = 3.10
# calling dusty with tstar = 8216.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0827; R_V = 3.10
# calling dusty with tstar = 7596.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0799; R_V = 3.10
# calling dusty with tstar = 4846.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4601; R_V = 3.10
# calling dusty with tstar = 6978.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2456; R_V = 3.10
# calling dusty with tstar = 5646.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4175; R_V = 3.10
# calling dusty with tstar = 13116.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0867; R_V = 3.10
# calling dusty with tstar = 4779.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.0511; R_V = 3.10
# calling dusty with tstar = 6945.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3431; R_V = 3.10
# calling dusty with tstar = 8463.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0838; R_V = 3.10
# calling dusty with tstar = 9976.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1906; R_V = 3.10
# calling dusty with tstar = 4905.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2745; R_V = 3.10
# calling dusty with tstar = 7961.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2435; R_V = 3.10
# calling dusty with tstar = 5010.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4457; R_V = 3.10
# calling dusty with tstar = 10736.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3230; R_V = 3.10
# calling dusty with tstar = 4054.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.1489; R_V = 3.10
# calling dusty with tstar = 6673.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3890; R_V = 3.10
# calling dusty with tstar = 8042.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1296; R_V = 3.10
# calling dusty with tstar = 7176.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2203; R_V = 3.10
# calling dusty with tstar = 4750.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2646; R_V = 3.10
# calling dusty with tstar = 6937.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2646; R_V = 3.10
# calling dusty with tstar = 7225.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3882; R_V = 3.10
# calling dusty with tstar = 12071.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2981; R_V = 3.10
# calling dusty with tstar = 4783.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.0968; R_V = 3.10
# calling dusty with tstar = 6433.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3735; R_V = 3.10
# calling dusty with tstar = 10404.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0328; R_V = 3.10
# calling dusty with tstar = 8708.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4232; R_V = 3.10
# calling dusty with tstar = 5506.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2336; R_V = 3.10
# calling dusty with tstar = 6694.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3172; R_V = 3.10
# calling dusty with tstar = 6474.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2391; R_V = 3.10
# calling dusty with tstar = 9289.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2982; R_V = 3.10
# calling dusty with tstar = 4898.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.0442; R_V = 3.10
# calling dusty with tstar = 6310.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3708; R_V = 3.10
# calling dusty with tstar = 6813.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1800; R_V = 3.10
# calling dusty with tstar = 8981.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4567; R_V = 3.10
# calling dusty with tstar = 5483.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2298; R_V = 3.10
# calling dusty with tstar = 7054.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3442; R_V = 3.10
# calling dusty with tstar = 7460.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5075; R_V = 3.10
# calling dusty with tstar = 9383.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2876; R_V = 3.10
# calling dusty with tstar = 4197.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3028; R_V = 3.10
# calling dusty with tstar = 6228.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2019; R_V = 3.10
# calling dusty with tstar = 9079.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4155; R_V = 3.10
# calling dusty with tstar = 5698.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3300; R_V = 3.10
# calling dusty with tstar = 4873.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3972; R_V = 3.10
# calling dusty with tstar = 8098.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5833; R_V = 3.10
# calling dusty with tstar = 11021.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2477; R_V = 3.10
# calling dusty with tstar = 6410.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3775; R_V = 3.10
# calling dusty with tstar = 4817.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.0859; R_V = 3.10
# calling dusty with tstar = 12981.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8445; R_V = 3.10
# calling dusty with tstar = 6346.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6335; R_V = 3.10
# calling dusty with tstar = 6107.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1735; R_V = 3.10
# calling dusty with tstar = 6608.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2794; R_V = 3.10
# calling dusty with tstar = 10775.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5031; R_V = 3.10
# calling dusty with tstar = 5258.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1241; R_V = 3.10
# calling dusty with tstar = 6457.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3540; R_V = 3.10
# calling dusty with tstar = 19230.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.5567; R_V = 3.10
# calling dusty with tstar = 5890.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4200; R_V = 3.10
# calling dusty with tstar = 6320.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3128; R_V = 3.10
# calling dusty with tstar = 6632.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2676; R_V = 3.10
# calling dusty with tstar = 11188.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5208; R_V = 3.10
# calling dusty with tstar = 5520.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2469; R_V = 3.10
# calling dusty with tstar = 6373.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3477; R_V = 3.10
# calling dusty with tstar = 13884.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9474; R_V = 3.10
# calling dusty with tstar = 5934.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4135; R_V = 3.10
# calling dusty with tstar = 6106.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2560; R_V = 3.10
# calling dusty with tstar = 6358.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2142; R_V = 3.10
# calling dusty with tstar = 11226.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5227; R_V = 3.10
# calling dusty with tstar = 5208.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1164; R_V = 3.10
# calling dusty with tstar = 6484.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3310; R_V = 3.10
# calling dusty with tstar = 5059.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.0387; R_V = 3.10
# calling dusty with tstar = 12388.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8042; R_V = 3.10
# calling dusty with tstar = 5256.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3995; R_V = 3.10
# calling dusty with tstar = 6357.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2137; R_V = 3.10
# calling dusty with tstar = 11068.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5195; R_V = 3.10
# calling dusty with tstar = 4681.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.0996; R_V = 3.10
# calling dusty with tstar = 6684.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3705; R_V = 3.10
# calling dusty with tstar = 3528.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.2148; R_V = 3.10
# calling dusty with tstar = 12108.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7713; R_V = 3.10
# calling dusty with tstar = 5990.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4102; R_V = 3.10
# calling dusty with tstar = 7261.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3173; R_V = 3.10
# calling dusty with tstar = 6495.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2226; R_V = 3.10
# calling dusty with tstar = 11002.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5160; R_V = 3.10
# calling dusty with tstar = 3963.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.2786; R_V = 3.10
# calling dusty with tstar = 8139.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4780; R_V = 3.10
# calling dusty with tstar = 4296.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.2537; R_V = 3.10
# calling dusty with tstar = 16294.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.2621; R_V = 3.10
# calling dusty with tstar = 5348.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1603; R_V = 3.10
# calling dusty with tstar = 5092.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1453; R_V = 3.10
# calling dusty with tstar = 6407.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2090; R_V = 3.10
# calling dusty with tstar = 8779.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3761; R_V = 3.10
# calling dusty with tstar = 4487.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.1750; R_V = 3.10
# calling dusty with tstar = 9880.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6682; R_V = 3.10
# calling dusty with tstar = 3909.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.4060; R_V = 3.10
# calling dusty with tstar = 13184.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0197; R_V = 3.10
# calling dusty with tstar = 3918.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0000; R_V = 3.10
# calling dusty with tstar = 8539.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3852; R_V = 3.10
# calling dusty with tstar = 6415.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2100; R_V = 3.10
# calling dusty with tstar = 13191.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6619; R_V = 3.10
# calling dusty with tstar = 11667.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8685; R_V = 3.10
# calling dusty with tstar = 13572.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8391; R_V = 3.10
# calling dusty with tstar = 5055.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0461; R_V = 3.10
# calling dusty with tstar = 6325.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3220; R_V = 3.10
# calling dusty with tstar = 8112.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5490; R_V = 3.10
# calling dusty with tstar = 20753.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.2344; R_V = 3.10
# calling dusty with tstar = 4239.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.2245; R_V = 3.10
# calling dusty with tstar = 9457.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6397; R_V = 3.10
# calling dusty with tstar = 3770.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.4479; R_V = 3.10
# calling dusty with tstar = 13473.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7933; R_V = 3.10
# calling dusty with tstar = 5793.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3300; R_V = 3.10
# calling dusty with tstar = 4185.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1049; R_V = 3.10
# calling dusty with tstar = 4975.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4793; R_V = 3.10
# calling dusty with tstar = 13030.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5872; R_V = 3.10
# calling dusty with tstar = 11009.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6991; R_V = 3.10
# calling dusty with tstar = 4270.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.2973; R_V = 3.10
# calling dusty with tstar = 12056.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7391; R_V = 3.10
# calling dusty with tstar = 5121.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0530; R_V = 3.10
# calling dusty with tstar = 6376.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3240; R_V = 3.10
# calling dusty with tstar = 9621.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8813; R_V = 3.10
# calling dusty with tstar = 10502.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4872; R_V = 3.10
# calling dusty with tstar = 4584.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.1158; R_V = 3.10
# calling dusty with tstar = 9793.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6623; R_V = 3.10
# calling dusty with tstar = 13600.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7978; R_V = 3.10
# calling dusty with tstar = 5566.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1933; R_V = 3.10
# calling dusty with tstar = 5891.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1994; R_V = 3.10
# calling dusty with tstar = 11900.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.3832; R_V = 3.10
# calling dusty with tstar = 11138.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4844; R_V = 3.10
# calling dusty with tstar = 10653.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6929; R_V = 3.10
# calling dusty with tstar = 13994.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9434; R_V = 3.10
# calling dusty with tstar = 5222.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0629; R_V = 3.10
# calling dusty with tstar = 8677.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3507; R_V = 3.10
# calling dusty with tstar = 9113.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6057; R_V = 3.10
# calling dusty with tstar = 15192.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5769; R_V = 3.10
# calling dusty with tstar = 11254.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7270; R_V = 3.10
# calling dusty with tstar = 21990.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.9636; R_V = 3.10
# calling dusty with tstar = 6377.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5001; R_V = 3.10
# calling dusty with tstar = 10513.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3870; R_V = 3.10
# calling dusty with tstar = 13850.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.4889; R_V = 3.10
# calling dusty with tstar = 18957.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7297; R_V = 3.10
# calling dusty with tstar = 10964.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7106; R_V = 3.10
# calling dusty with tstar = 5826.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.0071; R_V = 3.10
# calling dusty with tstar = 16101.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8526; R_V = 3.10
# calling dusty with tstar = 5291.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0454; R_V = 3.10
# calling dusty with tstar = 9941.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6526; R_V = 3.10
# calling dusty with tstar = 22188.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7574; R_V = 3.10
# calling dusty with tstar = 11641.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7489; R_V = 3.10
# calling dusty with tstar = 14370.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8797; R_V = 3.10
# calling dusty with tstar = 5520.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2288; R_V = 3.10
# calling dusty with tstar = 6218.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2307; R_V = 3.10
# calling dusty with tstar = 13596.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6839; R_V = 3.10
# calling dusty with tstar = 16213.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5679; R_V = 3.10
# calling dusty with tstar = 11379.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7364; R_V = 3.10
# calling dusty with tstar = 5942.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0631; R_V = 3.10
# calling dusty with tstar = 15192.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8669; R_V = 3.10
# calling dusty with tstar = 5710.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1542; R_V = 3.10
# calling dusty with tstar = 4425.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0550; R_V = 3.10
# calling dusty with tstar = 12378.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0275; R_V = 3.10
# calling dusty with tstar = 26451.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8980; R_V = 3.10
# calling dusty with tstar = 4088.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.2634; R_V = 3.10
# calling dusty with tstar = 13092.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9042; R_V = 3.10
# calling dusty with tstar = 8942.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3238; R_V = 3.10
# calling dusty with tstar = 17030.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0539; R_V = 3.10
# calling dusty with tstar = 4969.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.0365; R_V = 3.10
# calling dusty with tstar = 7422.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4516; R_V = 3.10
# calling dusty with tstar = 19174.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6370; R_V = 3.10
# calling dusty with tstar = 4648.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.1192; R_V = 3.10
# calling dusty with tstar = 11043.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7034; R_V = 3.10
# calling dusty with tstar = 5856.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0968; R_V = 3.10
# calling dusty with tstar = 22543.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.3768; R_V = 3.10
# calling dusty with tstar = 5587.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2026; R_V = 3.10
# calling dusty with tstar = 7394.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4927; R_V = 3.10
# calling dusty with tstar = 3818.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3670; R_V = 3.10
# calling dusty with tstar = 24640.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9279; R_V = 3.10
# calling dusty with tstar = 12437.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7839; R_V = 3.10
# calling dusty with tstar = 5941.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1185; R_V = 3.10
# calling dusty with tstar = 24396.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.7519; R_V = 3.10
# calling dusty with tstar = 5530.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1830; R_V = 3.10
# calling dusty with tstar = 5447.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4436; R_V = 3.10
# calling dusty with tstar = 7652.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4668; R_V = 3.10
# calling dusty with tstar = 22202.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8329; R_V = 3.10
# calling dusty with tstar = 4690.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.1099; R_V = 3.10
# calling dusty with tstar = 16194.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0328; R_V = 3.10
# calling dusty with tstar = 5770.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1453; R_V = 3.10
# calling dusty with tstar = 25629.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.7479; R_V = 3.10
# calling dusty with tstar = 5431.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1984; R_V = 3.10
# calling dusty with tstar = 7675.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5529; R_V = 3.10
# calling dusty with tstar = 8977.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6931; R_V = 3.10
# calling dusty with tstar = 19070.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7725; R_V = 3.10
# calling dusty with tstar = 3965.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.4114; R_V = 3.10
# calling dusty with tstar = 11293.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7539; R_V = 3.10
# calling dusty with tstar = 6220.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2415; R_V = 3.10
# calling dusty with tstar = 14907.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9291; R_V = 3.10
# calling dusty with tstar = 4835.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.0497; R_V = 3.10
# calling dusty with tstar = 7842.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5887; R_V = 3.10
# calling dusty with tstar = 6591.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6305; R_V = 3.10
# calling dusty with tstar = 28193.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7539; R_V = 3.10
# calling dusty with tstar = 4061.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.3714; R_V = 3.10
# calling dusty with tstar = 11314.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7179; R_V = 3.10
# calling dusty with tstar = 6483.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2847; R_V = 3.10
# calling dusty with tstar = 15668.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0204; R_V = 3.10
# calling dusty with tstar = 5506.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0866; R_V = 3.10
# calling dusty with tstar = 5652.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5709; R_V = 3.10
# calling dusty with tstar = 10607.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6983; R_V = 3.10
# calling dusty with tstar = 18522.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6754; R_V = 3.10
# calling dusty with tstar = 3604.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.4873; R_V = 3.10
# calling dusty with tstar = 11301.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7175; R_V = 3.10
# calling dusty with tstar = 5403.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1764; R_V = 3.10
# calling dusty with tstar = 16300.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0642; R_V = 3.10
# calling dusty with tstar = 3688.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0331; R_V = 3.10
# calling dusty with tstar = 11957.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.6332; R_V = 3.10
# calling dusty with tstar = 15480.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.1871; R_V = 3.10
# calling dusty with tstar = 17975.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4533; R_V = 3.10
# calling dusty with tstar = 11804.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7314; R_V = 3.10
# calling dusty with tstar = 17826.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.1772; R_V = 3.10
# calling dusty with tstar = 7742.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3155; R_V = 3.10
# calling dusty with tstar = 8610.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3603; R_V = 3.10
# calling dusty with tstar = 32315.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7874; R_V = 3.10
# calling dusty with tstar = 13428.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7900; R_V = 3.10
# calling dusty with tstar = 5648.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1904; R_V = 3.10
# calling dusty with tstar = 21245.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.4542; R_V = 3.10
# calling dusty with tstar = 8740.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3737; R_V = 3.10
# calling dusty with tstar = 6765.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1956; R_V = 3.10
# calling dusty with tstar = 18381.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.2298; R_V = 3.10
# calling dusty with tstar = 4838.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1866; R_V = 3.10
# calling dusty with tstar = 13475.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.2943; R_V = 3.10
# calling dusty with tstar = 7253.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4817; R_V = 3.10
# calling dusty with tstar = 3760.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1260; R_V = 3.10
# calling dusty with tstar = 4236.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.3509; R_V = 3.10
# calling dusty with tstar = 10198.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5031; R_V = 3.10
# calling dusty with tstar = 5786.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2911; R_V = 3.10
# calling dusty with tstar = 15950.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0120; R_V = 3.10
# calling dusty with tstar = 3619.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.0810; R_V = 3.10
# calling dusty with tstar = 30908.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7702; R_V = 3.10
# calling dusty with tstar = 4485.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.2650; R_V = 3.10
# calling dusty with tstar = 14347.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8709; R_V = 3.10
# calling dusty with tstar = 5440.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3249; R_V = 3.10
# calling dusty with tstar = 21437.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9233; R_V = 3.10
# calling dusty with tstar = 9435.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4354; R_V = 3.10
# calling dusty with tstar = 8323.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5106; R_V = 3.10
# calling dusty with tstar = 4032.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.4208; R_V = 3.10
# calling dusty with tstar = 14454.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8412; R_V = 3.10
# calling dusty with tstar = 9337.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4346; R_V = 3.10
# calling dusty with tstar = 30619.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.6324; R_V = 3.10
# calling dusty with tstar = 8153.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4613; R_V = 3.10
# calling dusty with tstar = 9600.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7877; R_V = 3.10
# calling dusty with tstar = 36142.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7659; R_V = 3.10
# calling dusty with tstar = 5365.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.3179; R_V = 3.10
# calling dusty with tstar = 16403.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8641; R_V = 3.10
# calling dusty with tstar = 9726.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4699; R_V = 3.10
# calling dusty with tstar = 17223.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7602; R_V = 3.10
# calling dusty with tstar = 6522.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4361; R_V = 3.10
# calling dusty with tstar = 4026.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2125; R_V = 3.10
# calling dusty with tstar = 9643.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6791; R_V = 3.10
# calling dusty with tstar = 28280.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6804; R_V = 3.10
# calling dusty with tstar = 4250.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.3459; R_V = 3.10
# calling dusty with tstar = 15080.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8939; R_V = 3.10
# calling dusty with tstar = 9794.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2978; R_V = 3.10
# calling dusty with tstar = 29868.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.8383; R_V = 3.10
# calling dusty with tstar = 7151.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2360; R_V = 3.10
# calling dusty with tstar = 13974.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8022; R_V = 3.10
# calling dusty with tstar = 13459.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6144; R_V = 3.10
# calling dusty with tstar = 21954.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9433; R_V = 3.10
# calling dusty with tstar = 5284.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0810; R_V = 3.10
# calling dusty with tstar = 8089.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4576; R_V = 3.10
# calling dusty with tstar = 12365.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.1965; R_V = 3.10
# calling dusty with tstar = 3509.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.5010; R_V = 3.10
# calling dusty with tstar = 9114.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7163; R_V = 3.10
# calling dusty with tstar = 9706.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5193; R_V = 3.10
# calling dusty with tstar = 15178.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0280; R_V = 3.10
# calling dusty with tstar = 7248.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2757; R_V = 3.10
# calling dusty with tstar = 6755.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4067; R_V = 3.10
# calling dusty with tstar = 10983.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9337; R_V = 3.10
# calling dusty with tstar = 36403.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7668; R_V = 3.10
# calling dusty with tstar = 4228.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.3500; R_V = 3.10
# calling dusty with tstar = 8107.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5492; R_V = 3.10
# calling dusty with tstar = 12370.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6208; R_V = 3.10
# calling dusty with tstar = 16040.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.1365; R_V = 3.10
# calling dusty with tstar = 6639.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3058; R_V = 3.10
# calling dusty with tstar = 6084.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2059; R_V = 3.10
# calling dusty with tstar = 10244.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6662; R_V = 3.10
# calling dusty with tstar = 32370.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8400; R_V = 3.10
# calling dusty with tstar = 4306.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.3369; R_V = 3.10
# calling dusty with tstar = 11831.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8249; R_V = 3.10
# calling dusty with tstar = 13552.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6989; R_V = 3.10
# calling dusty with tstar = 13376.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9393; R_V = 3.10
# calling dusty with tstar = 5602.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0202; R_V = 3.10
# calling dusty with tstar = 10659.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6703; R_V = 3.10
# calling dusty with tstar = 22760.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6405; R_V = 3.10
# calling dusty with tstar = 5467.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.0170; R_V = 3.10
# calling dusty with tstar = 9285.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7445; R_V = 3.10
# calling dusty with tstar = 10007.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4648; R_V = 3.10
# calling dusty with tstar = 20542.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.9475; R_V = 3.10
# calling dusty with tstar = 5231.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2257; R_V = 3.10
# calling dusty with tstar = 9588.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6195; R_V = 3.10
# calling dusty with tstar = 7460.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4395; R_V = 3.10
# calling dusty with tstar = 17561.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9268; R_V = 3.10
# calling dusty with tstar = 12374.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7983; R_V = 3.10
# calling dusty with tstar = 7209.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1887; R_V = 3.10
# calling dusty with tstar = 33141.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8416; R_V = 3.10
# calling dusty with tstar = 8966.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8940; R_V = 3.10
# calling dusty with tstar = 27391.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.6277; R_V = 3.10
# calling dusty with tstar = 17327.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8087; R_V = 3.10
# calling dusty with tstar = 5363.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3064; R_V = 3.10
# calling dusty with tstar = 19547.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5222; R_V = 3.10
# calling dusty with tstar = 38011.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9491; R_V = 3.10
# calling dusty with tstar = 8684.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5654; R_V = 3.10
# calling dusty with tstar = 14097.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7299; R_V = 3.10
# calling dusty with tstar = 26685.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.6320; R_V = 3.10
# calling dusty with tstar = 7840.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7419; R_V = 3.10
# calling dusty with tstar = 38140.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9521; R_V = 3.10
# calling dusty with tstar = 4331.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.3292; R_V = 3.10
# calling dusty with tstar = 11675.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6496; R_V = 3.10
# calling dusty with tstar = 22218.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.2193; R_V = 3.10
# calling dusty with tstar = 26914.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.6481; R_V = 3.10
# calling dusty with tstar = 7449.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3518; R_V = 3.10
# calling dusty with tstar = 5814.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.0624; R_V = 3.10
# calling dusty with tstar = 5186.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.0683; R_V = 3.10
# calling dusty with tstar = 13019.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7443; R_V = 3.10
# calling dusty with tstar = 17447.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8692; R_V = 3.10
# calling dusty with tstar = 18589.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8275; R_V = 3.10
# calling dusty with tstar = 9622.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3943; R_V = 3.10
# calling dusty with tstar = 9337.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4584; R_V = 3.10
# calling dusty with tstar = 11916.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3049; R_V = 3.10
# calling dusty with tstar = 4893.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.2066; R_V = 3.10
# calling dusty with tstar = 16782.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.1042; R_V = 3.10
# calling dusty with tstar = 17704.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9130; R_V = 3.10
# calling dusty with tstar = 8452.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7629; R_V = 3.10
# calling dusty with tstar = 11939.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5975; R_V = 3.10
# calling dusty with tstar = 9590.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4192; R_V = 3.10
# calling dusty with tstar = 6981.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1498; R_V = 3.10
# calling dusty with tstar = 3641.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.4203; R_V = 3.10
# calling dusty with tstar = 11702.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6515; R_V = 3.10
# calling dusty with tstar = 26250.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.4330; R_V = 3.10
# calling dusty with tstar = 9308.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7684; R_V = 3.10
# calling dusty with tstar = 8614.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5879; R_V = 3.10
# calling dusty with tstar = 4917.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.0933; R_V = 3.10
# calling dusty with tstar = 7070.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1650; R_V = 3.10
# calling dusty with tstar = 31781.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9116; R_V = 3.10
# calling dusty with tstar = 4574.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.2312; R_V = 3.10
# calling dusty with tstar = 9802.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5008; R_V = 3.10
# calling dusty with tstar = 17786.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9050; R_V = 3.10
# calling dusty with tstar = 23916.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0256; R_V = 3.10
# calling dusty with tstar = 8501.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5840; R_V = 3.10
# calling dusty with tstar = 4546.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0838; R_V = 3.10
# calling dusty with tstar = 5455.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.0335; R_V = 3.10
# calling dusty with tstar = 37324.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9896; R_V = 3.10
# calling dusty with tstar = 13579.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6412; R_V = 3.10
# calling dusty with tstar = 16917.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8511; R_V = 3.10
# calling dusty with tstar = 29945.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.4173; R_V = 3.10
# calling dusty with tstar = 9882.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6278; R_V = 3.10
# calling dusty with tstar = 5255.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.0783; R_V = 3.10
# calling dusty with tstar = 5365.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.1031; R_V = 3.10
# calling dusty with tstar = 16265.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8349; R_V = 3.10
# calling dusty with tstar = 12669.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0558; R_V = 3.10
# calling dusty with tstar = 10680.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7570; R_V = 3.10
# calling dusty with tstar = 4953.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.0092; R_V = 3.10
# calling dusty with tstar = 6817.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1339; R_V = 3.10
# calling dusty with tstar = 31699.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0047; R_V = 3.10
# calling dusty with tstar = 5429.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.1178; R_V = 3.10
# calling dusty with tstar = 8623.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3559; R_V = 3.10
# calling dusty with tstar = 14515.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9424; R_V = 3.10
# calling dusty with tstar = 14370.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.3315; R_V = 3.10
# calling dusty with tstar = 11119.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8849; R_V = 3.10
# calling dusty with tstar = 4978.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.0065; R_V = 3.10
# ...
# calling dusty with tstar = 5011.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = -0.1085; R_V = 3.10
# calling dusty with tstar = 15944.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7371; R_V = 3.10
# calling dusty with tstar = 10275.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8984; R_V = 3.10
# calling dusty with tstar = 26811.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8230; R_V = 3.10
# calling dusty with tstar = 15277.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7131; R_V = 3.10
# calling dusty with tstar = 26215.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8873; R_V = 3.10
# calling dusty with tstar = 13320.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8672; R_V = 3.10
# calling dusty with tstar = 37020.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9203; R_V = 3.10
# calling dusty with tstar = 36450.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.1738; R_V = 3.10
# calling dusty with tstar = 5341.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.0291; R_V = 3.10
# calling dusty with tstar = 14617.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7650; R_V = 3.10
# calling dusty with tstar = 25364.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8859; R_V = 3.10
# calling dusty with tstar = 22658.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9446; R_V = 3.10
# calling dusty with tstar = 31363.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8811; R_V = 3.10
# calling dusty with tstar = 9721.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5450; R_V = 3.10
# calling dusty with tstar = 35058.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0937; R_V = 3.10
# calling dusty with tstar = 15087.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7281; R_V = 3.10
# calling dusty with tstar = 21911.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8806; R_V = 3.10
# calling dusty with tstar = 9662.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7329; R_V = 3.10
# calling dusty with tstar = 14698.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8693; R_V = 3.10
# calling dusty with tstar = 23568.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8078; R_V = 3.10
# calling dusty with tstar = 9211.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5276; R_V = 3.10
# calling dusty with tstar = 15074.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7327; R_V = 3.10
# calling dusty with tstar = 21467.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9000; R_V = 3.10
# calling dusty with tstar = 10380.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7327; R_V = 3.10
# calling dusty with tstar = 15107.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8712; R_V = 3.10
# calling dusty with tstar = 30831.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8720; R_V = 3.10
# calling dusty with tstar = 10910.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5648; R_V = 3.10
# calling dusty with tstar = 11604.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7021; R_V = 3.10
# calling dusty with tstar = 28856.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.1346; R_V = 3.10
# calling dusty with tstar = 8572.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4802; R_V = 3.10
# calling dusty with tstar = 17667.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9202; R_V = 3.10
# calling dusty with tstar = 36371.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0552; R_V = 3.10
# calling dusty with tstar = 29233.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0356; R_V = 3.10
# calling dusty with tstar = 11978.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7759; R_V = 3.10
# calling dusty with tstar = 26178.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0496; R_V = 3.10
# calling dusty with tstar = 13917.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6531; R_V = 3.10
# calling dusty with tstar = 19609.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9498; R_V = 3.10
# calling dusty with tstar = 27396.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7584; R_V = 3.10
# calling dusty with tstar = 27418.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9890; R_V = 3.10
# calling dusty with tstar = 11810.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.2430; R_V = 3.10
# calling dusty with tstar = 16700.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8300; R_V = 3.10
# calling dusty with tstar = 19345.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8326; R_V = 3.10
# calling dusty with tstar = 14789.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5979; R_V = 3.10
# calling dusty with tstar = 14009.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6558; R_V = 3.10
# calling dusty with tstar = 8398.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3231; R_V = 3.10
# calling dusty with tstar = 26451.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9818; R_V = 3.10
# calling dusty with tstar = 17147.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4195; R_V = 3.10
# calling dusty with tstar = 11040.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8353; R_V = 3.10
# calling dusty with tstar = 22364.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9285; R_V = 3.10
# calling dusty with tstar = 20287.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.1165; R_V = 3.10
# calling dusty with tstar = 16639.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8942; R_V = 3.10
# calling dusty with tstar = 18374.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7651; R_V = 3.10
# calling dusty with tstar = 29129.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9233; R_V = 3.10
# calling dusty with tstar = 12045.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5168; R_V = 3.10
# calling dusty with tstar = 12191.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7847; R_V = 3.10
# calling dusty with tstar = 17903.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7869; R_V = 3.10
# calling dusty with tstar = 20040.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.1219; R_V = 3.10
# calling dusty with tstar = 19562.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9661; R_V = 3.10
# calling dusty with tstar = 36839.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0637; R_V = 3.10
# calling dusty with tstar = 14042.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8661; R_V = 3.10
# calling dusty with tstar = 33479.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9038; R_V = 3.10
# calling dusty with tstar = 9087.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.3895; R_V = 3.10
# calling dusty with tstar = 14575.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8434; R_V = 3.10
# calling dusty with tstar = 18310.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7785; R_V = 3.10
# calling dusty with tstar = 20742.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.1383; R_V = 3.10
# calling dusty with tstar = 21268.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0081; R_V = 3.10
# calling dusty with tstar = 36091.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0281; R_V = 3.10
# calling dusty with tstar = 12170.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9046; R_V = 3.10
# calling dusty with tstar = 27805.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0083; R_V = 3.10
# calling dusty with tstar = 18672.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4622; R_V = 3.10
# calling dusty with tstar = 11075.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6760; R_V = 3.10
# calling dusty with tstar = 10006.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6620; R_V = 3.10
# calling dusty with tstar = 20948.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.1531; R_V = 3.10
# calling dusty with tstar = 22936.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0594; R_V = 3.10
# calling dusty with tstar = 16524.1; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9334; R_V = 3.10
# calling dusty with tstar = 38892.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0818; R_V = 3.10
# calling dusty with tstar = 6500.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1228; R_V = 3.10
# calling dusty with tstar = 15666.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8978; R_V = 3.10
# calling dusty with tstar = 5356.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.4683; R_V = 3.10
# calling dusty with tstar = 22988.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.2447; R_V = 3.10
# calling dusty with tstar = 22204.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0431; R_V = 3.10
# calling dusty with tstar = 36665.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0391; R_V = 3.10
# calling dusty with tstar = 16118.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9166; R_V = 3.10
# calling dusty with tstar = 39698.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0973; R_V = 3.10
# calling dusty with tstar = 15964.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9102; R_V = 3.10
# calling dusty with tstar = 11725.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7157; R_V = 3.10
# calling dusty with tstar = 16384.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9367; R_V = 3.10
# calling dusty with tstar = 18822.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9375; R_V = 3.10
# calling dusty with tstar = 36468.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0353; R_V = 3.10
# calling dusty with tstar = 20937.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.1337; R_V = 3.10
# calling dusty with tstar = 35677.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0665; R_V = 3.10
# calling dusty with tstar = 16121.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9201; R_V = 3.10
# calling dusty with tstar = 21039.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.1574; R_V = 3.10
# calling dusty with tstar = 20267.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9826; R_V = 3.10
# calling dusty with tstar = 28613.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7961; R_V = 3.10
# calling dusty with tstar = 20904.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.1322; R_V = 3.10
# calling dusty with tstar = 15952.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9175; R_V = 3.10
# calling dusty with tstar = 6363.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6901; R_V = 3.10
# calling dusty with tstar = 16175.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9274; R_V = 3.10
# calling dusty with tstar = 18929.7; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9624; R_V = 3.10
# calling dusty with tstar = 26441.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8170; R_V = 3.10
# calling dusty with tstar = 16456.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9316; R_V = 3.10
# calling dusty with tstar = 6658.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.1326; R_V = 3.10
# calling dusty with tstar = 15635.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9087; R_V = 3.10
# calling dusty with tstar = 10409.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.6556; R_V = 3.10
# calling dusty with tstar = 18714.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.1293; R_V = 3.10
# calling dusty with tstar = 20723.0; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9977; R_V = 3.10
# calling dusty with tstar = 20586.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.7580; R_V = 3.10
# calling dusty with tstar = 7020.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8653; R_V = 3.10
# calling dusty with tstar = 27241.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0977; R_V = 3.10
# calling dusty with tstar = 15872.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9129; R_V = 3.10
# calling dusty with tstar = 8255.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.5328; R_V = 3.10
# calling dusty with tstar = 13633.6; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.1481; R_V = 3.10
# calling dusty with tstar = 20023.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9716; R_V = 3.10
# calling dusty with tstar = 19274.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8011; R_V = 3.10
# calling dusty with tstar = 10896.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.8925; R_V = 3.10
# calling dusty with tstar = 37491.9; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.0775; R_V = 3.10
# calling dusty with tstar = 15344.5; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9302; R_V = 3.10
# calling dusty with tstar = 18353.4; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.1302; R_V = 3.10
# calling dusty with tstar = 19074.3; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9120; R_V = 3.10
# calling dusty with tstar = 25811.8; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 1.1474; R_V = 3.10
# calling dusty with tstar = 16849.2; tau = 0.00; td = 250.0; thick = 2.00; amin = 0.005 amax = 0.250; E(B-V) = 0.9320; R_V = 3.10
# 2358.26224804
# (1600, 2)

# %%
#let's plot the results
fig = corner.corner(samples[500:], labels=["$T_{*}$", "$E(B-V)$"],
                      truths=[5116, 0.2])
fig.set_size_inches(10,10)
sampler.acceptance_fraction
# Out:
# array([ 0.555,  0.33 ,  0.675,  0.615,  0.54 ,  0.595,  0.455,  0.58 ])
